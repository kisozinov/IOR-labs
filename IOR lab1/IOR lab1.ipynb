# %% [markdown]
# # Лабораторная работа №1

# %% [markdown]
# Выполнили студенты 19ПМИ-2: Созинов Кирилл, Хорев Егор, Назаров Вячеслав

# %%
import numpy as np
import time
import os
from statistics import mean

# %% [markdown]
# ### Наивный алгоритм

# %%
def NAI(haystack, needle):
    start = time.time()
    index = -1
    operations = 0
    ind = 0
    n = len(haystack)
    m = len(needle)
    for i in range(0,n-m+1):
        for j in range(0,m):
            operations += 1
            if needle[j]!=haystack[i+j]:
                break
            if j==m-1:
                ind = i
                wtime = (time.time() - start) * 10**3
                return ind, wtime, operations

# %% [markdown]
# ### Алгоритм Рабина-Карпа

# %%
def makehash(word):
    Hash=0
    circle_module = 1000000000 + 7
    prime_number = 1007
    for i in range(len(word)):
        Hash = (Hash * prime_number + ord(word[i])) % circle_module
    return Hash


def RK(string, pattern):
    operations = 0
    start = time.time()
    n, m = len(string), len(pattern)
    hashpattern = makehash(pattern);
    for i in range(n-m+1):
        operations+=1
        hashstring = makehash(string[i:i+m])
        if hashstring == hashpattern:
            operations+=1
            if string[i:i+m] == pattern:
                wtime = (time.time() - start) * 10**3
                return i, wtime, operations
            else: 
                return -1

# %% [markdown]
# ###  Алгоритм Кнута–Морриса-Пратта

# %%
def KMP(haystack, needle):
    start = time.time()
    def prefix_function(S):
        nonlocal operations
        Pf = np.zeros(len(S))
        k = 0
        flag = False
        for i in range(1, len(S)):
            k = int(Pf[i-1])
            while S[i] != S[k]:
                operations += 1
                if k == 0:
                    Pf[i] = 0
                    flag = True
                    break
                else:
                    k = int(Pf[k-1])
            if not flag:
                Pf[i] = k + 1
            flag = False
        #print(Pf)
        return Pf
    
    index = -1
    operations = 0
    F, k, i = prefix_function(needle), 0, 0
    for i in range(len(haystack)):
        while haystack[i] != needle[k] and k > 0:
            operations += 1
            k = int(F[k-1])
        if haystack[i] == needle[k]:
            k += 1
        operations += 1
        if k == len(needle):
            wtime = (time.time() - start) * 10**3
            #print('Working time: ', (time.time() - start) * 10**3, 'ms')
            #print('Total operations: ', operations)
            return i - len(needle) + 1, wtime, operations
    #print('Working time: ', (time.time() - start)*1000, 'ms')
    #print('Total operations: ', operations)
    return index, wtime, operations

# %%
def get_staticstics(algorithm):
    '''
        На вход подается функция, выполняющая поиск подстроки в строке:
    -Функция должна возвращать индекс, время работы и количество операций
        В результате работы печатается статистика работы на наборе данных 
    '''
    filenames = os.listdir(str(os.getcwd() + '\\benchmarks'))
    for filename in filenames:
        if filename[:5] == 'bad_t':
            pattern = filenames[filenames.index('bad_w_' + filename[6] + '.txt')]
            print(filename, pattern)
            with open(os.getcwd() + '\\benchmarks\\' + filename, 'r', encoding='utf-8') as f1, open(os.getcwd() + '\\benchmarks\\' + pattern, 'r', encoding='utf-8') as f2:
                haystack, needle = f1.read(), f2.read()
                times = []
                for i in range(10):
                    idx, t, o = algorithm(haystack,needle)
                    times.append(t)
                idx, t, o = algorithm(haystack,needle)
                print('Index: ',idx)
                print('Average working time: ', "{0:.3f}".format(mean(times)), 'ms')
                print('Operations: ', o, '\n\n')
        if filename[:6] == 'good_t':
            pattern = filenames[filenames.index('good_w_' + filename[7] + '.txt')]
            print(filename, pattern)
            with open(os.getcwd() + '\\benchmarks\\' + filename, 'r', encoding='utf-8') as f1, open(os.getcwd() + '\\benchmarks\\' + pattern, 'r', encoding='utf-8') as f2:
                haystack, needle = f1.read(), f2.read()
                times = []
                for i in range(10):
                    idx, t, o = algorithm(haystack,needle)
                    times.append(t)
                idx, t, o = algorithm(haystack,needle)
                print('Index: ',idx)
                print('Average working time: ', "{0:.3f}".format(mean(times)), 'ms')
                print('Operations: ', o, '\n\n')

# %%
get_staticstics(NAI)
# Out:
# bad_t_1.txt bad_w_1.txt
# Index:  8
# Average working time:  0.000 ms
# Operations:  18
#
#
# bad_t_2.txt bad_w_2.txt
# Index:  90
# Average working time:  0.100 ms
# Operations:  910
#
#
# bad_t_3.txt bad_w_3.txt
# Index:  900
# Average working time:  12.100 ms
# Operations:  90100
#
#
# bad_t_4.txt bad_w_4.txt
# Index:  4000
# Average working time:  619.800 ms
# Operations:  4001000
#
#
# good_t_1.txt good_w_1.txt
# Index:  599
# Average working time:  0.300 ms
# Operations:  633
#
#
# good_t_2.txt good_w_2.txt
# Index:  610
# Average working time:  0.200 ms
# Operations:  695
#
#
# good_t_3.txt good_w_3.txt
# Index:  1629
# Average working time:  0.700 ms
# Operations:  2074
#
#
# good_t_4.txt good_w_4.txt
# Index:  9522
# Average working time:  3.400 ms
# Operations:  9614

# %%
get_staticstics(RK)
# Out:
# bad_t_1.txt bad_w_1.txt
# Index:  8
# Average working time:  0.000 ms
# Operations:  10
#
#
# bad_t_2.txt bad_w_2.txt
# Index:  90
# Average working time:  0.200 ms
# Operations:  92
#
#
# bad_t_3.txt bad_w_3.txt
# Index:  900
# Average working time:  16.200 ms
# Operations:  902
#
#
# bad_t_4.txt bad_w_4.txt
# Index:  4000
# Average working time:  729.200 ms
# Operations:  4002
#
#
# good_t_1.txt good_w_1.txt
# Index:  599
# Average working time:  2.300 ms
# Operations:  601
#
#
# good_t_2.txt good_w_2.txt
# Index:  610
# Average working time:  10.400 ms
# Operations:  612
#
#
# good_t_3.txt good_w_3.txt
# Index:  1629
# Average working time:  131.400 ms
# Operations:  1631
#
#
# good_t_4.txt good_w_4.txt
# Index:  9522
# Average working time:  182.800 ms
# Operations:  9524

# %%
get_staticstics(KMP)
# Out:
# bad_t_1.txt bad_w_1.txt
# Index:  8
# Average working time:  0.000 ms
# Operations:  19
#
#
# bad_t_2.txt bad_w_2.txt
# Index:  90
# Average working time:  0.100 ms
# Operations:  199
#
#
# bad_t_3.txt bad_w_3.txt
# Index:  900
# Average working time:  0.700 ms
# Operations:  1999
#
#
# bad_t_4.txt bad_w_4.txt
# Index:  4000
# Average working time:  3.200 ms
# Operations:  9999
#
#
# good_t_1.txt good_w_1.txt
# Index:  599
# Average working time:  0.200 ms
# Operations:  649
#
#
# good_t_2.txt good_w_2.txt
# Index:  610
# Average working time:  0.300 ms
# Operations:  779
#
#
# good_t_3.txt good_w_3.txt
# Index:  1629
# Average working time:  0.900 ms
# Operations:  2445
#
#
# good_t_4.txt good_w_4.txt
# Index:  9522
# Average working time:  3.200 ms
# Operations:  9705
